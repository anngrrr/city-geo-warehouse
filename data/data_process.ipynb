# %%
# %cd data
# Out:
# c:\Users\anngr\Code\ML-portfolio\city-geo-warehouse\data

# %%
import pandas as pd

# %%
data = pd.read_csv('.\WB_ESG_WIDEF.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\anngr\AppData\Local\Temp\ipykernel_23084\761342852.py:1: SyntaxWarning: invalid escape sequence '\W'
#   data = pd.read_csv('.\WB_ESG_WIDEF.csv')

# %%
# data[data.columns[data.nunique() > 1]].sort_values('2021-Q4')
data[data.columns[data.nunique() > 1]]
# Out:
#       REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0          AFG    Afghanistan     WB_ESG_AG_LND_AGRI_ZS
# 1          AFG    Afghanistan     WB_ESG_AG_LND_FRLS_HA
# 2          AFG    Afghanistan     WB_ESG_AG_LND_FRST_ZS
# 3          AFG    Afghanistan     WB_ESG_AG_PRD_FOOD_XD
# 4          AFG    Afghanistan             WB_ESG_CC_EST
# ...        ...            ...                       ...
# 14653      ZWE       Zimbabwe     WB_ESG_SP_DYN_LE00_IN
# 14654      ZWE       Zimbabwe     WB_ESG_SP_DYN_TFRT_IN
# 14655      ZWE       Zimbabwe  WB_ESG_SP_POP_65UP_TO_ZS
# 14656      ZWE       Zimbabwe        WB_ESG_SP_UWT_TFRT
# 14657      ZWE       Zimbabwe             WB_ESG_VA_EST
#
#                                          INDICATOR_LABEL     AGE  \
# 0                     Agricultural land (% of land area)      _T
# 1                             Tree Cover Loss (hectares)      _T
# 2                           Forest area (% of land area)      _T
# ...
